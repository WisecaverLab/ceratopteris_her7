# %%
library(pheatmap)

# %%
# test = matrix(rnorm(200), 20, 10)
# test[1:10, seq(1, 10, 2)] = test[1:10, seq(1, 10, 2)] + 3
# test[11:20, seq(2, 10, 2)] = test[11:20, seq(2, 10, 2)] + 2
# test[15:20, seq(2, 10, 2)] = test[15:20, seq(2, 10, 2)] + 4
# colnames(test) = paste("Test", 1:10, sep = "")
# rownames(test) = paste("Gene", 1:20, sep = "")

# head(test)
# annotation_row = data.frame(
#                     GeneClass = factor(rep(c("Path1", "Path2", "Path3"), c(10, 4, 6))),
#                   AdditionalAnnotation = c(rep("random1", 10), rep("random2", 10))
#                 )
# rownames(annotation_row) = paste("Gene", 1:20, sep = "")

# head(annotation_row)

# %%
df = read.table("gene_expression.Rin", sep = '\t', header = TRUE)
#subset$de <- as.character(subset$de)

# %% [markdown]
# # BR signaling

# %%
subdf = subset(df, path=='BR signaling')
expdf = subdf[c('spore1','spore2','FM1','FM2','FM3','ACE1','ACE2','ACE3','her19_1','her19_2','her19_3','male_1','male_2','male_3')]

expmx = as.matrix(expdf, rownames=TRUE)
rownames(expmx) = subdf$gene
#expmx = log(expmx+1)

anndf = subdf[c('DE_males_v_her19','DE_ACE_v_FM', 'gene_family')]
rownames(anndf) = subdf$gene

# %%
palette = colorRampPalette(c('#FFFFE5', '#FFF7BC', '#FEE391', '#FEC44F', '#FB9A29', '#EC7014', '#CC4C02', '#993404', '#662506'))(100)

my_colour = list(
    gene_family = c('BRI1' = '#AA4499', 
        'BRL2' = '#882255', 
        'BAK1' = '#CC6677', 
        'BSK' = '#DDCC77', 
        'BSU1' = '#999933', 
        'BIN2' = '#117733', 
        'BZR1_2' = '#44AA99'),       
    DE_males_v_her19 = c('up in WT males' = '#B2182B', 'not de' = '#F7F7F7', 'up in her19 hermaphrodites' = '#2166AC', 'not expressed' = '#FFEE99' ),
    DE_ACE_v_FM = c('up in Ace+' = '#B2182B', 'not de' = '#F7F7F7', 'up in Ace-' = '#2166AC', 'not expressed' = '#FFEE99' )
    
)

# %%
save_pheatmap_pdf <- function(x, filename, width=7, height=10) {
   stopifnot(!missing(x))
   stopifnot(!missing(filename))
   pdf(filename, width=width, height=height)
   grid::grid.newpage()
   grid::grid.draw(x$gtable)
   dev.off()
}

# %%
fig = pheatmap(expmx, main = 'BR signaling\nrlog(normalized counts)', 
        cellwidth = 12, cellheight = 12, cluster_cols = FALSE, cluster_rows = FALSE, 
        annotation_colors = my_colour, annotation_row = anndf, color = palette)
save_pheatmap_pdf(fig, "BR_signaling_heatmap.pdf")
# Out:
# png
#   2
# plot without title

# %% [markdown]
# # BR biosynthesis

# %%
subdf = subset(df, path=='BR biosynthesis')
expdf = subdf[c('spore1','spore2','FM1','FM2','FM3','ACE1','ACE2','ACE3','her19_1','her19_2','her19_3','male_1','male_2','male_3')]

expmx = as.matrix(expdf, rownames=TRUE)
rownames(expmx) = subdf$gene
#expmx = log(expmx+1)

anndf = subdf[c('DE_males_v_her19','DE_ACE_v_FM', 'gene_family')]
rownames(anndf) = subdf$gene

# %%
palette = colorRampPalette(c('#FFFFE5', '#FFF7BC', '#FEE391', '#FEC44F', '#FB9A29', '#EC7014', '#CC4C02', '#993404', '#662506'))(100)

my_colour = list(
    gene_family = c(
        'CYP90B1/DWF4' = '#AA3377', 
        'CYP90A1/CPD' = '#EE6677', 
        'CYP90C1/ROT3' = '#CCBB44'
    ),       
    DE_males_v_her19 = c('up in WT males' = '#B2182B', 'not de' = '#F7F7F7', 'up in her19 hermaphrodites' = '#2166AC', 'not expressed' = '#FFEE99' ),
    DE_ACE_v_FM = c('up in Ace+' = '#B2182B', 'not de' = '#F7F7F7', 'up in Ace-' = '#2166AC', 'not expressed' = '#FFEE99' )
)

# %%
save_pheatmap_pdf <- function(x, filename, width=7, height=10) {
   stopifnot(!missing(x))
   stopifnot(!missing(filename))
   pdf(filename, width=width, height=height)
   grid::grid.newpage()
   grid::grid.draw(x$gtable)
   dev.off()
}

# %%
fig = pheatmap(expmx, main = 'BR biosynthesis\nrlog(normalized counts)', cellwidth = 12, cellheight = 12, cluster_cols = FALSE, cluster_rows = FALSE, annotation_colors = my_colour, annotation_row = anndf, color = palette)
save_pheatmap_pdf(fig, "BR_biosynthesis_heatmap.pdf")
# Out:
# png
#   2
# plot without title

# %% [markdown]
# # GA signaling

# %%
subdf = subset(df, path=='GA signaling')
expdf = subdf[c('spore1','spore2','FM1','FM2','FM3','ACE1','ACE2','ACE3','her19_1','her19_2','her19_3','male_1','male_2','male_3')]

expmx = as.matrix(expdf, rownames=TRUE)
rownames(expmx) = subdf$gene
#expmx = log(expmx+1)

anndf = subdf[c('DE_males_v_her19','DE_ACE_v_FM', 'gene_family')]
rownames(anndf) = subdf$gene

# %%
palette = colorRampPalette(c('#FFFFE5', '#FFF7BC', '#FEE391', '#FEC44F', '#FB9A29', '#EC7014', '#CC4C02', '#993404', '#662506'))(100)

my_colour = list(
    gene_family = c(
        'GID1' = '#AA3377', 
        'GAI/DELLA' = '#EE6677', 
        'PIF4' = '#CCBB44'
    ),       
    DE_males_v_her19 = c('up in WT males' = '#B2182B', 'not de' = '#F7F7F7', 'up in her19 hermaphrodites' = '#2166AC', 'not expressed' = '#FFEE99' ),
    DE_ACE_v_FM = c('up in Ace+' = '#B2182B', 'not de' = '#F7F7F7', 'up in Ace-' = '#2166AC', 'not expressed' = '#FFEE99' )
)

# %%
save_pheatmap_pdf <- function(x, filename, width=7, height=10) {
   stopifnot(!missing(x))
   stopifnot(!missing(filename))
   pdf(filename, width=width, height=height)
   grid::grid.newpage()
   grid::grid.draw(x$gtable)
   dev.off()
}

# %%
fig = pheatmap(expmx, main = 'GA signaling\nrlog(normalized counts)', cellwidth = 12, cellheight = 12, cluster_cols = FALSE, cluster_rows = FALSE, annotation_colors = my_colour, annotation_row = anndf, color = palette)
save_pheatmap_pdf(fig, "GA_signaling_heatmap.pdf")
# Out:
# png
#   2
# plot without title

# %% [markdown]
# # GA biosynthesis

# %%
subdf = subset(df, path=='GA biosynthesis')
expdf = subdf[c('spore1','spore2','FM1','FM2','FM3','ACE1','ACE2','ACE3','her19_1','her19_2','her19_3','male_1','male_2','male_3')]

expmx = as.matrix(expdf, rownames=TRUE)
rownames(expmx) = subdf$gene
#expmx = log(expmx+1)

anndf = subdf[c('DE_males_v_her19','DE_ACE_v_FM', 'gene_family')]
rownames(anndf) = subdf$gene

# %%
palette = colorRampPalette(c('#FFFFE5', '#FFF7BC', '#FEE391', '#FEC44F', '#FB9A29', '#EC7014', '#CC4C02', '#993404', '#662506'))(100)

my_colour = list(
    gene_family = c(
        'CPS-KS/GA1' = '#AA3377', 
        'CYP701/GA3' = '#EE6677', 
        'CYP88A3/KAO' = '#CCBB44', 
        'GA20OX' = '#228833', 
        'GA3OX/GA4H' = '#66CCEE'
    ),       
    DE_males_v_her19 = c('up in WT males' = '#B2182B', 'not de' = '#F7F7F7', 'up in her19 hermaphrodites' = '#2166AC', 'not expressed' = '#FFEE99' ),
    DE_ACE_v_FM = c('up in Ace+' = '#B2182B', 'not de' = '#F7F7F7', 'up in Ace-' = '#2166AC', 'not expressed' = '#FFEE99' )
)

# %%
save_pheatmap_pdf <- function(x, filename, width=7, height=10) {
   stopifnot(!missing(x))
   stopifnot(!missing(filename))
   pdf(filename, width=width, height=height)
   grid::grid.newpage()
   grid::grid.draw(x$gtable)
   dev.off()
}

# %%
fig = pheatmap(expmx, main = 'GA biosynthesis\nrlog(normalized counts)', cellwidth = 12, cellheight = 12, cluster_cols = FALSE, cluster_rows = FALSE, annotation_colors = my_colour, annotation_row = anndf, color = palette)
save_pheatmap_pdf(fig, "GA_biosynthesis_heatmap.pdf")
# Out:
# png
#   2
# plot without title

# %% [markdown]
# # Other interesting gene families

# %%
subdf = subset(df, path=='other')
expdf = subdf[c('spore1','spore2','FM1','FM2','FM3','ACE1','ACE2','ACE3','her19_1','her19_2','her19_3','male_1','male_2','male_3')]

expmx = as.matrix(expdf, rownames=TRUE)
rownames(expmx) = subdf$gene
#expmx = log(expmx+1)

anndf = subdf[c('DE_males_v_her19','DE_ACE_v_FM', 'gene_family')]
rownames(anndf) = subdf$gene

# %%
palette = colorRampPalette(c('#FFFFE5', '#FFF7BC', '#FEE391', '#FEC44F', '#FB9A29', '#EC7014', '#CC4C02', '#993404', '#662506'))(100)

my_colour = list(
    gene_family = c(
        'CYCD3' = '#AA3377', 
        'TCH4' = '#EE6677', 
        'DET2' = '#CCBB44', 
        'BAS1' = '#228833', 
        'CYP87' = '#66CCEE' 
    ),       
    DE_males_v_her19 = c('up in WT males' = '#B2182B', 'not de' = '#F7F7F7', 'up in her19 hermaphrodites' = '#2166AC', 'not expressed' = '#FFEE99' ),
    DE_ACE_v_FM = c('up in Ace+' = '#B2182B', 'not de' = '#F7F7F7', 'up in Ace-' = '#2166AC', 'not expressed' = '#FFEE99' )
)

# %%
save_pheatmap_pdf <- function(x, filename, width=7, height=10) {
   stopifnot(!missing(x))
   stopifnot(!missing(filename))
   pdf(filename, width=width, height=height)
   grid::grid.newpage()
   grid::grid.draw(x$gtable)
   dev.off()
}

# %%
fig = pheatmap(expmx, main = 'other gene families\nrlog(normalized counts)', cellwidth = 12, cellheight = 12, cluster_cols = FALSE, cluster_rows = FALSE, annotation_colors = my_colour, annotation_row = anndf, color = palette)
save_pheatmap_pdf(fig, "other_genes_heatmap.pdf")
# Out:
# png
#   2
# plot without title
